# %% [markdown]
# # Run With Folium Using Kaggle Example

# %%
import streamlit as st
import folium
from folium.plugins import HeatMap
import pandas as pd

# Create a base map
m_5 = folium.Map(location=[5.32,100.0589], tiles='cartodbpositron', zoom_start=12)

test = pd.read_csv("Flood Data Updated Geocoded.csv")

# Add a heatmap to the base map
HeatMap(data=test[['Latitude', 'Longitude']], radius=10).add_to(m_5)

# Display the map
m_5

# %% [markdown]
# # Check Code For Streamlit

# %%
import leafmap.foliumap as leafmap
m = leafmap.Map(center=[5, -100], zoom=4)
cities = 'Flood Data Updated Geocoded.csv'
regions = 'countries.geojson'

m.add_geojson(regions)
m.add_points_from_xy(
    cities,
    x="Longitude",
    y="Latitude",
    icon_names=['gear', 'map', 'leaf', 'globe'],
)

# runnable, need to check deployment status

# %% [markdown]
# # Testing Nominatim - Error due to change of device

# %%
import geopy
from geopy.geocoders import Nominatim
import ssl

ctx = ssl.create_default_context(cafile=certifi.where())
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE

geopy.geocoders.options.default_ssl_context = ctx

geolocator = Nominatim(user_agent="u2004763@siswa.um.edu.my", scheme='http')
location = geolocator.geocode("Johor Bahru") # testing

print(location.point)
print(location.address)

# %%
import os
os.environ['CURL_CA_BUNDLE'] = ''

import certifi
import ssl
import geopy.geocoders
from geopy.geocoders import Nominatim
ctx = ssl.create_default_context(cafile=certifi.where())
geopy.geocoders.options.default_ssl_context = ctx

geolocator = Nominatim(scheme='http', user_agent="u2004763@siswa.um.edu.my")
location = geolocator.reverse("48.8588443, 2.2943506")

print(location.address)
print (location.raw)

# %%
import pandas as pd
import numpy as np
import geopandas as gpd
from geopy.geocoders import Nominatim

geolocator = Nominatim(user_agent="u2004763@siswa.um.edu.my")

def my_geocoder(row):
    try:
        point = geolocator.geocode(row).point
        return pd.Series({'Latitude': point.latitude, 'Longitude': point.longitude})
    except:
        return None
    
df = pd.DataFrame({'x': ['Johor']})

df[['Latitude', 'Longitude']] = df.apply(lambda y: my_geocoder(y['x']), axis=1)
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17696\2807782632.py in ?()
#      13         return None
#      14
#      15 df = pd.DataFrame({'x': ['Johor']})
#      16
# ---> 17 df[['Latitude', 'Longitude']] = df.apply(lambda y: my_geocoder(y['x']), axis=1)
#      18 df
#
# ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\frame.py in ?(self, key, value)
#    3934
#    3935         if isinstance(key, DataFrame) or getattr(key, "ndim", None) == 2:
#    3936             self._setitem_frame(key, value)
#    3937         elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 3938             self._setitem_array(key, value)
#    3939         elif isinstance(value, DataFrame):
#    3940             self._set_item_frame_value(key, value)
#    3941         elif (
#
# ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\frame.py in ?(self, key, value)
#    3993                 value = DataFrame(value).values
#    3994                 return self._setitem_array(key, value)
#    3995
#    3996             else:
# -> 3997                 self._iset_not_inplace(key, value)
#
# ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\frame.py in ?(self, key, value)
#    4012                 return obj[i]
#    4013
#    4014         if self.columns.is_unique:
#    4015             if np.shape(value)[-1] != len(key):
# -> 4016                 raise ValueError("Columns must be same length as key")
#    4017
#    4018             for i, col in enumerate(key):
#    4019                 self[col] = igetitem(value, i)
#
# ValueError: Columns must be same length as key
